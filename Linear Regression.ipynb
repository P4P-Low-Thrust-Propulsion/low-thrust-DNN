# %%
#check the contents of the model 
#create a random seed 
torch.manual_seed(42)
#create an instance of the model (this is a subclass of nn.module)

model_0 = LinearRegressionModel()
#printing of the list 
list(model_0.parameters())
print(model_0.state_dict())
# Out:
# OrderedDict([('weight', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
#making prediction using 'torch.inference_model()'
with torch.inference_mode():
    y_preds=model_0(X_test)
y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
plot_predictions(predictions = y_preds)

#ideally the red dots are ontop of the green dots

# %%
#train the model, 

#the whole idea is to move the red dots to the green, unknown pararemeters to known parameters
#loss function 
#optomizer 


# setting up a loss function 
loss_fn=nn.L1Loss()

# setting up a optomizer 
optomizer = torch.optim.SGD(params = model_0.parameters(),
                            lr = 0.01) #lr = learning rate

# %%
#building the training loop and a testing loop 
#0. loop through the data 
#1. Forward pass (this involves data moving through our model's forward function 
#2. Calculate the loss  compare productions to ground thruth labels 
#3. loss backward - move backwards throguh the network to calcuate the gradients of each of the parameters of our model with respoec to the loss
#4. use the optimizer to adjust our models parameters to tru and improce the loss 


#an epoch is one loop through the data 
######TRAINING LOOP ##########################
epochs = 1000
epoch_count = []
loss_values = []
test_loss_values = []

for epoch in range(epochs):
    model_0.train() 
    # 1 forward pass 
    y_preds = model_0(X_train)
    # 2 calculate the loss 
    loss = loss_fn(y_preds,y_train)
    # 3 optomizer zero grad 
    optomizer.zero_grad()
    # 4 perfrom back propogation on the loss with respect to the parameters of the model 
    loss.backward()
    # 5. step the optimizer (perform gradeint descent )
    optomizer.step() # by deful how the optimzer changes will acculumate through the loop so we have to zero them above in step 3
    
    #TESTING
    model_0.eval() #tunrs off diffrence setting sin th emodel not needed evaluating/testing
    with torch.inference_mode():
        # 1. forward 
        test_pred = model_0(X_test)
        #2. lest 
        test_loss = loss_fn(test_pred,y_test)
        
    if epoch%10==0:
        epoch_count.append(epoch)
        loss_values.append(loss)
        test_loss_values.append(test_loss)
        print(f"Epoch: {epoch} | Test: {loss} | Test loss: {test_loss}")
    
    
    print(f"Loss:{loss}" )
    print(model_0.state_dict())
# Out:
# Epoch: 0 | Test: 0.535663366317749 | Test loss: 1.340118646621704
# Loss:0.535663366317749
# OrderedDict([('weight', tensor([0.3405])), ('bias', tensor([0.1368]))])
# Loss:0.5279914140701294
# OrderedDict([('weight', tensor([0.3443])), ('bias', tensor([0.1443]))])
# Loss:0.5209223031997681
# OrderedDict([('weight', tensor([0.3481])), ('bias', tensor([0.1518]))])
# Loss:0.5138534307479858
# OrderedDict([('weight', tensor([0.3519])), ('bias', tensor([0.1593]))])
# Loss:0.5067843794822693
# OrderedDict([('weight', tensor([0.3557])), ('bias', tensor([0.1668]))])
# Loss:0.49983447790145874
# OrderedDict([('weight', tensor([0.3595])), ('bias', tensor([0.1738]))])
# Loss:0.4935282766819
# OrderedDict([('weight', tensor([0.3632])), ('bias', tensor([0.1808]))])
# Loss:0.48722201585769653
# OrderedDict([('weight', tensor([0.3670])), ('bias', tensor([0.1878]))])
# Loss:0.48091578483581543
# OrderedDict([('weight', tensor([0.3707])), ('bias', tensor([0.1948]))])
# Loss:0.4746095538139343
# OrderedDict([('weight', tensor([0.3745])), ('bias', tensor([0.2018]))])
# Epoch: 10 | Test: 0.4686407148838043 | Test loss: 1.2351189851760864
# Loss:0.4686407148838043
# OrderedDict([('weight', tensor([0.3782])), ('bias', tensor([0.2083]))])
# Loss:0.46305403113365173
# OrderedDict([('weight', tensor([0.3819])), ('bias', tensor([0.2148]))])
# Loss:0.45746737718582153
# OrderedDict([('weight', tensor([0.3856])), ('bias', tensor([0.2213]))])
# Loss:0.4518807828426361
# OrderedDict([('weight', tensor([0.3892])), ('bias', tensor([0.2278]))])
# Loss:0.44640931487083435
# OrderedDict([('weight', tensor([0.3929])), ('bias', tensor([0.2338]))])
# Loss:0.44149890542030334
# OrderedDict([('weight', tensor([0.3965])), ('bias', tensor([0.2398]))])
# Loss:0.43658846616744995
# OrderedDict([('weight', tensor([0.4001])), ('bias', tensor([0.2458]))])
# Loss:0.43167799711227417
# OrderedDict([('weight', tensor([0.4037])), ('bias', tensor([0.2518]))])
# Loss:0.42676758766174316
# OrderedDict([('weight', tensor([0.4073])), ('bias', tensor([0.2578]))])
# Loss:0.4220063090324402
# OrderedDict([('weight', tensor([0.4109])), ('bias', tensor([0.2633]))])
# Epoch: 20 | Test: 0.41772812604904175 | Test loss: 1.1423566341400146
# Loss:0.41772812604904175
# OrderedDict([('weight', tensor([0.4144])), ('bias', tensor([0.2688]))])
# Loss:0.4134500026702881
# OrderedDict([('weight', tensor([0.4180])), ('bias', tensor([0.2743]))])
# Loss:0.4091718792915344
# OrderedDict([('weight', tensor([0.4215])), ('bias', tensor([0.2798]))])
# Loss:0.404893696308136
# OrderedDict([('weight', tensor([0.4250])), ('bias', tensor([0.2853]))])
# Loss:0.4007064402103424
# OrderedDict([('weight', tensor([0.4285])), ('bias', tensor([0.2903]))])
# Loss:0.39701610803604126
# OrderedDict([('weight', tensor([0.4319])), ('bias', tensor([0.2953]))])
# Loss:0.39332589507102966
# OrderedDict([('weight', tensor([0.4354])), ('bias', tensor([0.3003]))])
# Loss:0.3896356225013733
# OrderedDict([('weight', tensor([0.4388])), ('bias', tensor([0.3053]))])
# Loss:0.3859454095363617
# OrderedDict([('weight', tensor([0.4423])), ('bias', tensor([0.3103]))])
# Loss:0.3822551369667053
# OrderedDict([('weight', tensor([0.4457])), ('bias', tensor([0.3153]))])
# Epoch: 30 | Test: 0.3787877559661865 | Test loss: 1.0605000257492065
# Loss:0.3787877559661865
# OrderedDict([('weight', tensor([0.4491])), ('bias', tensor([0.3198]))])
# Loss:0.37564048171043396
# OrderedDict([('weight', tensor([0.4524])), ('bias', tensor([0.3243]))])
# Loss:0.3724932372570038
# OrderedDict([('weight', tensor([0.4558])), ('bias', tensor([0.3288]))])
# Loss:0.3693459928035736
# OrderedDict([('weight', tensor([0.4591])), ('bias', tensor([0.3333]))])
# Loss:0.36619871854782104
# OrderedDict([('weight', tensor([0.4625])), ('bias', tensor([0.3378]))])
# Loss:0.36305150389671326
# OrderedDict([('weight', tensor([0.4658])), ('bias', tensor([0.3423]))])
# Loss:0.3601439595222473
# OrderedDict([('weight', tensor([0.4691])), ('bias', tensor([0.3463]))])
# Loss:0.3574942350387573
# OrderedDict([('weight', tensor([0.4723])), ('bias', tensor([0.3503]))])
# Loss:0.35484445095062256
# OrderedDict([('weight', tensor([0.4756])), ('bias', tensor([0.3543]))])
# Loss:0.3521946966648102
# OrderedDict([('weight', tensor([0.4788])), ('bias', tensor([0.3583]))])
# Epoch: 40 | Test: 0.3495449423789978 | Test loss: 0.9886746406555176
# Loss:0.3495449423789978
# OrderedDict([('weight', tensor([0.4820])), ('bias', tensor([0.3623]))])
# Loss:0.3468951880931854
# OrderedDict([('weight', tensor([0.4853])), ('bias', tensor([0.3663]))])
# Loss:0.34438425302505493
# OrderedDict([('weight', tensor([0.4884])), ('bias', tensor([0.3698]))])
# Loss:0.3421857953071594
# OrderedDict([('weight', tensor([0.4915])), ('bias', tensor([0.3733]))])
# Loss:0.3399873375892639
# OrderedDict([('weight', tensor([0.4946])), ('bias', tensor([0.3768]))])
# Loss:0.3377889096736908
# OrderedDict([('weight', tensor([0.4978])), ('bias', tensor([0.3803]))])
# Loss:0.3355904817581177
# OrderedDict([('weight', tensor([0.5009])), ('bias', tensor([0.3838]))])
# Loss:0.3333919942378998
# OrderedDict([('weight', tensor([0.5040])), ('bias', tensor([0.3873]))])
# Loss:0.33119359612464905
# OrderedDict([('weight', tensor([0.5071])), ('bias', tensor([0.3908]))])
# Loss:0.3291281461715698
# OrderedDict([('weight', tensor([0.5101])), ('bias', tensor([0.3938]))])
# Epoch: 50 | Test: 0.32733413577079773 | Test loss: 0.926531195640564
# Loss:0.32733413577079773
# OrderedDict([('weight', tensor([0.5131])), ('bias', tensor([0.3968]))])
# Loss:0.32554012537002563
# OrderedDict([('weight', tensor([0.5161])), ('bias', tensor([0.3998]))])
# Loss:0.32374611496925354
# OrderedDict([('weight', tensor([0.5191])), ('bias', tensor([0.4028]))])
# Loss:0.32195210456848145
# OrderedDict([('weight', tensor([0.5221])), ('bias', tensor([0.4058]))])
# Loss:0.32015809416770935
# OrderedDict([('weight', tensor([0.5251])), ('bias', tensor([0.4088]))])
# Loss:0.31836411356925964
# OrderedDict([('weight', tensor([0.5281])), ('bias', tensor([0.4118]))])
# Loss:0.31657010316848755
# OrderedDict([('weight', tensor([0.5310])), ('bias', tensor([0.4148]))])
# Loss:0.3149511218070984
# OrderedDict([('weight', tensor([0.5339])), ('bias', tensor([0.4173]))])
# Loss:0.3135138750076294
# OrderedDict([('weight', tensor([0.5367])), ('bias', tensor([0.4198]))])
# Loss:0.3120766282081604
# OrderedDict([('weight', tensor([0.5396])), ('bias', tensor([0.4223]))])
# Epoch: 60 | Test: 0.310639351606369 | Test loss: 0.8724185824394226
# Loss:0.310639351606369
# OrderedDict([('weight', tensor([0.5424])), ('bias', tensor([0.4248]))])
# Loss:0.3092021346092224
# OrderedDict([('weight', tensor([0.5453])), ('bias', tensor([0.4273]))])
# Loss:0.30776485800743103
# OrderedDict([('weight', tensor([0.5481])), ('bias', tensor([0.4298]))])
# Loss:0.3063276410102844
# OrderedDict([('weight', tensor([0.5510])), ('bias', tensor([0.4323]))])
# Loss:0.30489033460617065
# OrderedDict([('weight', tensor([0.5538])), ('bias', tensor([0.4348]))])
# Loss:0.3035011887550354
# OrderedDict([('weight', tensor([0.5565])), ('bias', tensor([0.4368]))])
# Loss:0.3023722469806671
# OrderedDict([('weight', tensor([0.5592])), ('bias', tensor([0.4388]))])
# Loss:0.3012431859970093
# OrderedDict([('weight', tensor([0.5619])), ('bias', tensor([0.4408]))])
# Loss:0.300114244222641
# OrderedDict([('weight', tensor([0.5646])), ('bias', tensor([0.4428]))])
# Loss:0.2989852726459503
# OrderedDict([('weight', tensor([0.5673])), ('bias', tensor([0.4448]))])
# Epoch: 70 | Test: 0.29785624146461487 | Test loss: 0.8258548974990845
# Loss:0.29785624146461487
# OrderedDict([('weight', tensor([0.5700])), ('bias', tensor([0.4468]))])
# Loss:0.2967272400856018
# OrderedDict([('weight', tensor([0.5727])), ('bias', tensor([0.4488]))])
# Loss:0.29559826850891113
# OrderedDict([('weight', tensor([0.5754])), ('bias', tensor([0.4508]))])
# Loss:0.2944692373275757
# OrderedDict([('weight', tensor([0.5781])), ('bias', tensor([0.4528]))])
# Loss:0.293340265750885
# OrderedDict([('weight', tensor([0.5808])), ('bias', tensor([0.4548]))])
# Loss:0.29224517941474915
# OrderedDict([('weight', tensor([0.5834])), ('bias', tensor([0.4563]))])
# Loss:0.291375070810318
# OrderedDict([('weight', tensor([0.5859])), ('bias', tensor([0.4578]))])
# Loss:0.2905048727989197
# OrderedDict([('weight', tensor([0.5885])), ('bias', tensor([0.4593]))])
# Loss:0.28963473439216614
# OrderedDict([('weight', tensor([0.5910])), ('bias', tensor([0.4608]))])
# Loss:0.2887645363807678
# OrderedDict([('weight', tensor([0.5935])), ('bias', tensor([0.4623]))])
# Epoch: 80 | Test: 0.2878943681716919 | Test loss: 0.7856793403625488
# Loss:0.2878943681716919
# OrderedDict([('weight', tensor([0.5961])), ('bias', tensor([0.4638]))])
# Loss:0.28702419996261597
# OrderedDict([('weight', tensor([0.5986])), ('bias', tensor([0.4653]))])
# Loss:0.2861540615558624
# OrderedDict([('weight', tensor([0.6012])), ('bias', tensor([0.4668]))])
# Loss:0.2852838933467865
# OrderedDict([('weight', tensor([0.6037])), ('bias', tensor([0.4683]))])
# Loss:0.28441375494003296
# OrderedDict([('weight', tensor([0.6062])), ('bias', tensor([0.4698]))])
# Loss:0.28354358673095703
# OrderedDict([('weight', tensor([0.6088])), ('bias', tensor([0.4713]))])
# Loss:0.2826734185218811
# OrderedDict([('weight', tensor([0.6113])), ('bias', tensor([0.4728]))])
# Loss:0.28183621168136597
# OrderedDict([('weight', tensor([0.6137])), ('bias', tensor([0.4738]))])
# Loss:0.28117451071739197
# OrderedDict([('weight', tensor([0.6161])), ('bias', tensor([0.4748]))])
# Loss:0.28051283955574036
# OrderedDict([('weight', tensor([0.6184])), ('bias', tensor([0.4758]))])
# Epoch: 90 | Test: 0.27985113859176636 | Test loss: 0.750678539276123
# Loss:0.27985113859176636
# OrderedDict([('weight', tensor([0.6208])), ('bias', tensor([0.4768]))])
# Loss:0.27918940782546997
# OrderedDict([('weight', tensor([0.6232])), ('bias', tensor([0.4778]))])
# Loss:0.27852773666381836
# OrderedDict([('weight', tensor([0.6255])), ('bias', tensor([0.4788]))])
# Loss:0.27786606550216675
# OrderedDict([('weight', tensor([0.6279])), ('bias', tensor([0.4798]))])
# Loss:0.27720436453819275
# OrderedDict([('weight', tensor([0.6303])), ('bias', tensor([0.4808]))])
# Loss:0.27654266357421875
# OrderedDict([('weight', tensor([0.6327])), ('bias', tensor([0.4818]))])
# Loss:0.27588099241256714
# OrderedDict([('weight', tensor([0.6350])), ('bias', tensor([0.4828]))])
# Loss:0.2752193212509155
# OrderedDict([('weight', tensor([0.6374])), ('bias', tensor([0.4838]))])
# Loss:0.27455759048461914
# OrderedDict([('weight', tensor([0.6398])), ('bias', tensor([0.4848]))])
# Loss:0.27389591932296753
# OrderedDict([('weight', tensor([0.6421])), ('bias', tensor([0.4858]))])
# Epoch: 100 | Test: 0.2732342481613159 | Test loss: 0.719585657119751
# Loss:0.2732342481613159
# OrderedDict([('weight', tensor([0.6445])), ('bias', tensor([0.4868]))])
# Loss:0.2725725769996643
# OrderedDict([('weight', tensor([0.6469])), ('bias', tensor([0.4878]))])
# Loss:0.2719449996948242
# OrderedDict([('weight', tensor([0.6491])), ('bias', tensor([0.4883]))])
# Loss:0.2714403569698334
# OrderedDict([('weight', tensor([0.6513])), ('bias', tensor([0.4888]))])
# Loss:0.2709358036518097
# OrderedDict([('weight', tensor([0.6534])), ('bias', tensor([0.4893]))])
# Loss:0.27043119072914124
# OrderedDict([('weight', tensor([0.6556])), ('bias', tensor([0.4898]))])
# Loss:0.2699265778064728
# OrderedDict([('weight', tensor([0.6578])), ('bias', tensor([0.4903]))])
# Loss:0.2694219648838043
# OrderedDict([('weight', tensor([0.6600])), ('bias', tensor([0.4908]))])
# Loss:0.26891735196113586
# OrderedDict([('weight', tensor([0.6622])), ('bias', tensor([0.4913]))])
# Loss:0.2684127390384674
# OrderedDict([('weight', tensor([0.6644])), ('bias', tensor([0.4918]))])
# Epoch: 110 | Test: 0.26790809631347656 | Test loss: 0.6944345235824585
# Loss:0.26790809631347656
# OrderedDict([('weight', tensor([0.6666])), ('bias', tensor([0.4923]))])
# Loss:0.2674035131931305
# OrderedDict([('weight', tensor([0.6688])), ('bias', tensor([0.4928]))])
# Loss:0.2668989300727844
# OrderedDict([('weight', tensor([0.6710])), ('bias', tensor([0.4933]))])
# Loss:0.26639431715011597
# OrderedDict([('weight', tensor([0.6731])), ('bias', tensor([0.4938]))])
# Loss:0.2658897042274475
# OrderedDict([('weight', tensor([0.6753])), ('bias', tensor([0.4943]))])
# Loss:0.26538509130477905
# OrderedDict([('weight', tensor([0.6775])), ('bias', tensor([0.4948]))])
# Loss:0.2648804783821106
# OrderedDict([('weight', tensor([0.6797])), ('bias', tensor([0.4953]))])
# Loss:0.26437586545944214
# OrderedDict([('weight', tensor([0.6819])), ('bias', tensor([0.4958]))])
# Loss:0.2638712525367737
# OrderedDict([('weight', tensor([0.6841])), ('bias', tensor([0.4963]))])
# Loss:0.2633666396141052
# OrderedDict([('weight', tensor([0.6863])), ('bias', tensor([0.4968]))])
# Epoch: 120 | Test: 0.26286202669143677 | Test loss: 0.669943630695343
# Loss:0.26286202669143677
# OrderedDict([('weight', tensor([0.6885])), ('bias', tensor([0.4973]))])
# Loss:0.2623574137687683
# OrderedDict([('weight', tensor([0.6907])), ('bias', tensor([0.4978]))])
# Loss:0.2618660032749176
# OrderedDict([('weight', tensor([0.6927])), ('bias', tensor([0.4978]))])
# Loss:0.26146602630615234
# OrderedDict([('weight', tensor([0.6947])), ('bias', tensor([0.4978]))])
# Loss:0.2610660195350647
# OrderedDict([('weight', tensor([0.6967])), ('bias', tensor([0.4978]))])
# Loss:0.26066604256629944
# OrderedDict([('weight', tensor([0.6987])), ('bias', tensor([0.4978]))])
# Loss:0.2602660357952118
# OrderedDict([('weight', tensor([0.7007])), ('bias', tensor([0.4978]))])
# Loss:0.25986605882644653
# OrderedDict([('weight', tensor([0.7027])), ('bias', tensor([0.4978]))])
# Loss:0.2594659924507141
# OrderedDict([('weight', tensor([0.7047])), ('bias', tensor([0.4978]))])
# Loss:0.25906604528427124
# OrderedDict([('weight', tensor([0.7067])), ('bias', tensor([0.4978]))])
# Epoch: 130 | Test: 0.2586660385131836 | Test loss: 0.6514747738838196
# Loss:0.2586660385131836
# OrderedDict([('weight', tensor([0.7087])), ('bias', tensor([0.4978]))])
# Loss:0.25826606154441833
# OrderedDict([('weight', tensor([0.7107])), ('bias', tensor([0.4978]))])
# Loss:0.2578660547733307
# OrderedDict([('weight', tensor([0.7127])), ('bias', tensor([0.4978]))])
# Loss:0.25746607780456543
# OrderedDict([('weight', tensor([0.7147])), ('bias', tensor([0.4978]))])
# Loss:0.2570660710334778
# OrderedDict([('weight', tensor([0.7167])), ('bias', tensor([0.4978]))])
# Loss:0.25666606426239014
# OrderedDict([('weight', tensor([0.7187])), ('bias', tensor([0.4978]))])
# Loss:0.2562660574913025
# OrderedDict([('weight', tensor([0.7207])), ('bias', tensor([0.4978]))])
# Loss:0.2558661103248596
# OrderedDict([('weight', tensor([0.7227])), ('bias', tensor([0.4978]))])
# Loss:0.2554660737514496
# OrderedDict([('weight', tensor([0.7247])), ('bias', tensor([0.4978]))])
# Loss:0.2550660967826843
# OrderedDict([('weight', tensor([0.7267])), ('bias', tensor([0.4978]))])
# Epoch: 140 | Test: 0.25466611981391907 | Test loss: 0.6336749792098999
# Loss:0.25466611981391907
# OrderedDict([('weight', tensor([0.7287])), ('bias', tensor([0.4978]))])
# Loss:0.25426608324050903
# OrderedDict([('weight', tensor([0.7307])), ('bias', tensor([0.4978]))])
# Loss:0.2538661062717438
# OrderedDict([('weight', tensor([0.7327])), ('bias', tensor([0.4978]))])
# Loss:0.2534661293029785
# OrderedDict([('weight', tensor([0.7347])), ('bias', tensor([0.4978]))])
# Loss:0.25306615233421326
# OrderedDict([('weight', tensor([0.7367])), ('bias', tensor([0.4978]))])
# Loss:0.2526661455631256
# OrderedDict([('weight', tensor([0.7387])), ('bias', tensor([0.4978]))])
# Loss:0.25226613879203796
# OrderedDict([('weight', tensor([0.7407])), ('bias', tensor([0.4978]))])
# Loss:0.2518661618232727
# OrderedDict([('weight', tensor([0.7427])), ('bias', tensor([0.4978]))])
# Loss:0.25146615505218506
# OrderedDict([('weight', tensor([0.7447])), ('bias', tensor([0.4978]))])
# Loss:0.2510661482810974
# OrderedDict([('weight', tensor([0.7467])), ('bias', tensor([0.4978]))])
# Epoch: 150 | Test: 0.25066614151000977 | Test loss: 0.615875244140625
# Loss:0.25066614151000977
# OrderedDict([('weight', tensor([0.7487])), ('bias', tensor([0.4978]))])
# Loss:0.2502661645412445
# OrderedDict([('weight', tensor([0.7507])), ('bias', tensor([0.4978]))])
# Loss:0.24986615777015686
# OrderedDict([('weight', tensor([0.7527])), ('bias', tensor([0.4978]))])
# Loss:0.2494661509990692
# OrderedDict([('weight', tensor([0.7547])), ('bias', tensor([0.4978]))])
# Loss:0.24906615912914276
# OrderedDict([('weight', tensor([0.7567])), ('bias', tensor([0.4978]))])
# Loss:0.24869003891944885
# OrderedDict([('weight', tensor([0.7585])), ('bias', tensor([0.4973]))])
# Loss:0.24834099411964417
# OrderedDict([('weight', tensor([0.7603])), ('bias', tensor([0.4968]))])
# Loss:0.24799203872680664
# OrderedDict([('weight', tensor([0.7621])), ('bias', tensor([0.4963]))])
# Loss:0.24764299392700195
# OrderedDict([('weight', tensor([0.7639])), ('bias', tensor([0.4958]))])
# Loss:0.24729402363300323
# OrderedDict([('weight', tensor([0.7657])), ('bias', tensor([0.4953]))])
# Epoch: 160 | Test: 0.24694505333900452 | Test loss: 0.6021432876586914
# Loss:0.24694505333900452
# OrderedDict([('weight', tensor([0.7675])), ('bias', tensor([0.4948]))])
# Loss:0.24659602344036102
# OrderedDict([('weight', tensor([0.7693])), ('bias', tensor([0.4943]))])
# Loss:0.24624700844287872
# OrderedDict([('weight', tensor([0.7711])), ('bias', tensor([0.4938]))])
# Loss:0.24589800834655762
# OrderedDict([('weight', tensor([0.7729])), ('bias', tensor([0.4933]))])
# Loss:0.2455490082502365
# OrderedDict([('weight', tensor([0.7747])), ('bias', tensor([0.4928]))])
# Loss:0.2452000379562378
# OrderedDict([('weight', tensor([0.7765])), ('bias', tensor([0.4923]))])
# Loss:0.2448510378599167
# OrderedDict([('weight', tensor([0.7783])), ('bias', tensor([0.4918]))])
# Loss:0.2445020228624344
# OrderedDict([('weight', tensor([0.7801])), ('bias', tensor([0.4913]))])
# Loss:0.24415305256843567
# OrderedDict([('weight', tensor([0.7819])), ('bias', tensor([0.4908]))])
# Loss:0.24380402266979218
# OrderedDict([('weight', tensor([0.7837])), ('bias', tensor([0.4903]))])
# Epoch: 170 | Test: 0.24345502257347107 | Test loss: 0.5911232233047485
# Loss:0.24345502257347107
# OrderedDict([('weight', tensor([0.7855])), ('bias', tensor([0.4898]))])
# Loss:0.24310603737831116
# OrderedDict([('weight', tensor([0.7873])), ('bias', tensor([0.4893]))])
# Loss:0.24275705218315125
# OrderedDict([('weight', tensor([0.7891])), ('bias', tensor([0.4888]))])
# Loss:0.24240803718566895
# OrderedDict([('weight', tensor([0.7909])), ('bias', tensor([0.4883]))])
# Loss:0.24205903708934784
# OrderedDict([('weight', tensor([0.7927])), ('bias', tensor([0.4878]))])
# Loss:0.24171003699302673
# OrderedDict([('weight', tensor([0.7945])), ('bias', tensor([0.4873]))])
# Loss:0.24136102199554443
# OrderedDict([('weight', tensor([0.7963])), ('bias', tensor([0.4868]))])
# Loss:0.24101202189922333
# OrderedDict([('weight', tensor([0.7981])), ('bias', tensor([0.4863]))])
# Loss:0.24066302180290222
# OrderedDict([('weight', tensor([0.7999])), ('bias', tensor([0.4858]))])
# Loss:0.2403140515089035
# OrderedDict([('weight', tensor([0.8017])), ('bias', tensor([0.4853]))])
# Epoch: 180 | Test: 0.2399650514125824 | Test loss: 0.5801030993461609
# Loss:0.2399650514125824
# OrderedDict([('weight', tensor([0.8035])), ('bias', tensor([0.4848]))])
# Loss:0.2396160066127777
# OrderedDict([('weight', tensor([0.8053])), ('bias', tensor([0.4843]))])
# Loss:0.2392670214176178
# OrderedDict([('weight', tensor([0.8071])), ('bias', tensor([0.4838]))])
# Loss:0.23891803622245789
# OrderedDict([('weight', tensor([0.8089])), ('bias', tensor([0.4833]))])
# Loss:0.23856902122497559
# OrderedDict([('weight', tensor([0.8107])), ('bias', tensor([0.4828]))])
# Loss:0.23822005093097687
# OrderedDict([('weight', tensor([0.8125])), ('bias', tensor([0.4823]))])
# Loss:0.23787102103233337
# OrderedDict([('weight', tensor([0.8143])), ('bias', tensor([0.4818]))])
# Loss:0.23752203583717346
# OrderedDict([('weight', tensor([0.8161])), ('bias', tensor([0.4813]))])
# Loss:0.23717303574085236
# OrderedDict([('weight', tensor([0.8179])), ('bias', tensor([0.4808]))])
# Loss:0.23682403564453125
# OrderedDict([('weight', tensor([0.8197])), ('bias', tensor([0.4803]))])
# Epoch: 190 | Test: 0.23647503554821014 | Test loss: 0.5690830945968628
# Loss:0.23647503554821014
# OrderedDict([('weight', tensor([0.8215])), ('bias', tensor([0.4798]))])
# Loss:0.23612603545188904
# OrderedDict([('weight', tensor([0.8233])), ('bias', tensor([0.4793]))])
# Loss:0.23577705025672913
# OrderedDict([('weight', tensor([0.8251])), ('bias', tensor([0.4788]))])
# Loss:0.23542805016040802
# OrderedDict([('weight', tensor([0.8269])), ('bias', tensor([0.4783]))])
# Loss:0.23507902026176453
# OrderedDict([('weight', tensor([0.8287])), ('bias', tensor([0.4778]))])
# Loss:0.23473003506660461
# OrderedDict([('weight', tensor([0.8305])), ('bias', tensor([0.4773]))])
# Loss:0.23438100516796112
# OrderedDict([('weight', tensor([0.8323])), ('bias', tensor([0.4768]))])
# Loss:0.2340320646762848
# OrderedDict([('weight', tensor([0.8341])), ('bias', tensor([0.4763]))])
# Loss:0.23368306457996368
# OrderedDict([('weight', tensor([0.8359])), ('bias', tensor([0.4758]))])
# Loss:0.2333340346813202
# OrderedDict([('weight', tensor([0.8377])), ('bias', tensor([0.4753]))])
# Epoch: 200 | Test: 0.23298504948616028 | Test loss: 0.5580629706382751
# Loss:0.23298504948616028
# OrderedDict([('weight', tensor([0.8395])), ('bias', tensor([0.4748]))])
# Loss:0.23263604938983917
# OrderedDict([('weight', tensor([0.8413])), ('bias', tensor([0.4743]))])
# Loss:0.23228701949119568
# OrderedDict([('weight', tensor([0.8431])), ('bias', tensor([0.4738]))])
# Loss:0.23193803429603577
# OrderedDict([('weight', tensor([0.8449])), ('bias', tensor([0.4733]))])
# Loss:0.23158907890319824
# OrderedDict([('weight', tensor([0.8467])), ('bias', tensor([0.4728]))])
# Loss:0.23124003410339355
# OrderedDict([('weight', tensor([0.8485])), ('bias', tensor([0.4723]))])
# Loss:0.23089103400707245
# OrderedDict([('weight', tensor([0.8503])), ('bias', tensor([0.4718]))])
# Loss:0.23054203391075134
# OrderedDict([('weight', tensor([0.8521])), ('bias', tensor([0.4713]))])
# Loss:0.23019304871559143
# OrderedDict([('weight', tensor([0.8539])), ('bias', tensor([0.4708]))])
# Loss:0.22984401881694794
# OrderedDict([('weight', tensor([0.8557])), ('bias', tensor([0.4703]))])
# Epoch: 210 | Test: 0.22949504852294922 | Test loss: 0.547042965888977
# Loss:0.22949504852294922
# OrderedDict([('weight', tensor([0.8575])), ('bias', tensor([0.4698]))])
# Loss:0.22914603352546692
# OrderedDict([('weight', tensor([0.8593])), ('bias', tensor([0.4693]))])
# Loss:0.2287970334291458
# OrderedDict([('weight', tensor([0.8611])), ('bias', tensor([0.4688]))])
# Loss:0.22844800353050232
# OrderedDict([('weight', tensor([0.8629])), ('bias', tensor([0.4683]))])
# Loss:0.228099063038826
# OrderedDict([('weight', tensor([0.8647])), ('bias', tensor([0.4678]))])
# Loss:0.22775006294250488
# OrderedDict([('weight', tensor([0.8665])), ('bias', tensor([0.4673]))])
# Loss:0.22740104794502258
# OrderedDict([('weight', tensor([0.8683])), ('bias', tensor([0.4668]))])
# Loss:0.22705206274986267
# OrderedDict([('weight', tensor([0.8701])), ('bias', tensor([0.4663]))])
# Loss:0.22670301795005798
# OrderedDict([('weight', tensor([0.8719])), ('bias', tensor([0.4658]))])
# Loss:0.22635404765605927
# OrderedDict([('weight', tensor([0.8737])), ('bias', tensor([0.4653]))])
# Epoch: 220 | Test: 0.22600504755973816 | Test loss: 0.5360229015350342
# Loss:0.22600504755973816
# OrderedDict([('weight', tensor([0.8755])), ('bias', tensor([0.4648]))])
# Loss:0.22565603256225586
# OrderedDict([('weight', tensor([0.8773])), ('bias', tensor([0.4643]))])
# Loss:0.22530706226825714
# OrderedDict([('weight', tensor([0.8791])), ('bias', tensor([0.4638]))])
# Loss:0.22495803236961365
# OrderedDict([('weight', tensor([0.8809])), ('bias', tensor([0.4633]))])
# Loss:0.22460904717445374
# OrderedDict([('weight', tensor([0.8827])), ('bias', tensor([0.4628]))])
# Loss:0.22426006197929382
# OrderedDict([('weight', tensor([0.8845])), ('bias', tensor([0.4623]))])
# Loss:0.22391104698181152
# OrderedDict([('weight', tensor([0.8863])), ('bias', tensor([0.4618]))])
# Loss:0.22356204688549042
# OrderedDict([('weight', tensor([0.8881])), ('bias', tensor([0.4613]))])
# Loss:0.22321303188800812
# OrderedDict([('weight', tensor([0.8899])), ('bias', tensor([0.4608]))])
# Loss:0.2228640615940094
# OrderedDict([('weight', tensor([0.8917])), ('bias', tensor([0.4603]))])
# Epoch: 230 | Test: 0.2225150614976883 | Test loss: 0.5250028371810913
# Loss:0.2225150614976883
# OrderedDict([('weight', tensor([0.8935])), ('bias', tensor([0.4598]))])
# Loss:0.2221660166978836
# OrderedDict([('weight', tensor([0.8953])), ('bias', tensor([0.4593]))])
# Loss:0.2218170464038849
# OrderedDict([('weight', tensor([0.8971])), ('bias', tensor([0.4588]))])
# Loss:0.22146804630756378
# OrderedDict([('weight', tensor([0.8989])), ('bias', tensor([0.4583]))])
# Loss:0.2211190164089203
# OrderedDict([('weight', tensor([0.9007])), ('bias', tensor([0.4578]))])
# Loss:0.22077004611492157
# OrderedDict([('weight', tensor([0.9025])), ('bias', tensor([0.4573]))])
# Loss:0.22042103111743927
# OrderedDict([('weight', tensor([0.9043])), ('bias', tensor([0.4568]))])
# Loss:0.22007203102111816
# OrderedDict([('weight', tensor([0.9061])), ('bias', tensor([0.4563]))])
# Loss:0.21972303092479706
# OrderedDict([('weight', tensor([0.9079])), ('bias', tensor([0.4558]))])
# Loss:0.21937403082847595
# OrderedDict([('weight', tensor([0.9097])), ('bias', tensor([0.4553]))])
# Epoch: 240 | Test: 0.21902506053447723 | Test loss: 0.5139827132225037
# Loss:0.21902506053447723
# OrderedDict([('weight', tensor([0.9115])), ('bias', tensor([0.4548]))])
# Loss:0.21867604553699493
# OrderedDict([('weight', tensor([0.9133])), ('bias', tensor([0.4543]))])
# Loss:0.21832704544067383
# OrderedDict([('weight', tensor([0.9151])), ('bias', tensor([0.4538]))])
# Loss:0.21797804534435272
# OrderedDict([('weight', tensor([0.9169])), ('bias', tensor([0.4533]))])
# Loss:0.21762903034687042
# OrderedDict([('weight', tensor([0.9187])), ('bias', tensor([0.4528]))])
# Loss:0.2172800600528717
# OrderedDict([('weight', tensor([0.9205])), ('bias', tensor([0.4523]))])
# Loss:0.2169310301542282
# OrderedDict([('weight', tensor([0.9223])), ('bias', tensor([0.4518]))])
# Loss:0.2165820598602295
# OrderedDict([('weight', tensor([0.9241])), ('bias', tensor([0.4513]))])
# Loss:0.2162330448627472
# OrderedDict([('weight', tensor([0.9259])), ('bias', tensor([0.4508]))])
# Loss:0.21588405966758728
# OrderedDict([('weight', tensor([0.9277])), ('bias', tensor([0.4503]))])
# Epoch: 250 | Test: 0.21553504467010498 | Test loss: 0.5029626488685608
# Loss:0.21553504467010498
# OrderedDict([('weight', tensor([0.9295])), ('bias', tensor([0.4498]))])
# Loss:0.21519537270069122
# OrderedDict([('weight', tensor([0.9311])), ('bias', tensor([0.4488]))])
# Loss:0.2148498296737671
# OrderedDict([('weight', tensor([0.9329])), ('bias', tensor([0.4483]))])
# Loss:0.2145063877105713
# OrderedDict([('weight', tensor([0.9344])), ('bias', tensor([0.4473]))])
# Loss:0.2141646444797516
# OrderedDict([('weight', tensor([0.9362])), ('bias', tensor([0.4468]))])
# Loss:0.21381735801696777
# OrderedDict([('weight', tensor([0.9378])), ('bias', tensor([0.4458]))])
# Loss:0.2134794294834137
# OrderedDict([('weight', tensor([0.9396])), ('bias', tensor([0.4453]))])
# Loss:0.21313044428825378
# OrderedDict([('weight', tensor([0.9414])), ('bias', tensor([0.4448]))])
# Loss:0.21279218792915344
# OrderedDict([('weight', tensor([0.9430])), ('bias', tensor([0.4438]))])
# Loss:0.2124452292919159
# OrderedDict([('weight', tensor([0.9448])), ('bias', tensor([0.4433]))])
# Epoch: 260 | Test: 0.21210315823554993 | Test loss: 0.4953770041465759
# Loss:0.21210315823554993
# OrderedDict([('weight', tensor([0.9464])), ('bias', tensor([0.4423]))])
# Loss:0.2117600440979004
# OrderedDict([('weight', tensor([0.9482])), ('bias', tensor([0.4418]))])
# Loss:0.2114141434431076
# OrderedDict([('weight', tensor([0.9498])), ('bias', tensor([0.4408]))])
# Loss:0.2110748589038849
# OrderedDict([('weight', tensor([0.9516])), ('bias', tensor([0.4403]))])
# Loss:0.2107258290052414
# OrderedDict([('weight', tensor([0.9534])), ('bias', tensor([0.4398]))])
# Loss:0.2103889435529709
# OrderedDict([('weight', tensor([0.9550])), ('bias', tensor([0.4388]))])
# Loss:0.21004065871238708
# OrderedDict([('weight', tensor([0.9568])), ('bias', tensor([0.4383]))])
# Loss:0.20969991385936737
# OrderedDict([('weight', tensor([0.9584])), ('bias', tensor([0.4373]))])
# Loss:0.2093554437160492
# OrderedDict([('weight', tensor([0.9602])), ('bias', tensor([0.4368]))])
# Loss:0.20901091396808624
# OrderedDict([('weight', tensor([0.9618])), ('bias', tensor([0.4358]))])
# Epoch: 270 | Test: 0.2086702287197113 | Test loss: 0.48710447549819946
# Loss:0.2086702287197113
# OrderedDict([('weight', tensor([0.9636])), ('bias', tensor([0.4353]))])
# Loss:0.20832189917564392
# OrderedDict([('weight', tensor([0.9652])), ('bias', tensor([0.4343]))])
# Loss:0.2079850137233734
# OrderedDict([('weight', tensor([0.9670])), ('bias', tensor([0.4338]))])
# Loss:0.2076360285282135
# OrderedDict([('weight', tensor([0.9688])), ('bias', tensor([0.4333]))])
# Loss:0.207296684384346
# OrderedDict([('weight', tensor([0.9704])), ('bias', tensor([0.4323]))])
# Loss:0.2069508284330368
# OrderedDict([('weight', tensor([0.9722])), ('bias', tensor([0.4318]))])
# Loss:0.2066076695919037
# OrderedDict([('weight', tensor([0.9737])), ('bias', tensor([0.4308]))])
# Loss:0.2062656432390213
# OrderedDict([('weight', tensor([0.9755])), ('bias', tensor([0.4303]))])
# Loss:0.20591866970062256
# OrderedDict([('weight', tensor([0.9771])), ('bias', tensor([0.4293]))])
# Loss:0.2055804431438446
# OrderedDict([('weight', tensor([0.9789])), ('bias', tensor([0.4288]))])
# Epoch: 280 | Test: 0.2052314281463623 | Test loss: 0.478831946849823
# Loss:0.2052314281463623
# OrderedDict([('weight', tensor([0.9807])), ('bias', tensor([0.4283]))])
# Loss:0.20489346981048584
# OrderedDict([('weight', tensor([0.9823])), ('bias', tensor([0.4273]))])
# Loss:0.20454621315002441
# OrderedDict([('weight', tensor([0.9841])), ('bias', tensor([0.4268]))])
# Loss:0.20420444011688232
# OrderedDict([('weight', tensor([0.9857])), ('bias', tensor([0.4258]))])
# Loss:0.2038610279560089
# OrderedDict([('weight', tensor([0.9875])), ('bias', tensor([0.4253]))])
# Loss:0.2035154402256012
# OrderedDict([('weight', tensor([0.9891])), ('bias', tensor([0.4243]))])
# Loss:0.20317582786083221
# OrderedDict([('weight', tensor([0.9909])), ('bias', tensor([0.4238]))])
# Loss:0.2028268277645111
# OrderedDict([('weight', tensor([0.9927])), ('bias', tensor([0.4233]))])
# Loss:0.2024902105331421
# OrderedDict([('weight', tensor([0.9943])), ('bias', tensor([0.4223]))])
# Loss:0.20214161276817322
# OrderedDict([('weight', tensor([0.9961])), ('bias', tensor([0.4218]))])
# Epoch: 290 | Test: 0.20180121064186096 | Test loss: 0.47124624252319336
# Loss:0.20180121064186096
# OrderedDict([('weight', tensor([0.9977])), ('bias', tensor([0.4208]))])
# Loss:0.20145642757415771
# OrderedDict([('weight', tensor([0.9995])), ('bias', tensor([0.4203]))])
# Loss:0.20111222565174103
# OrderedDict([('weight', tensor([1.0011])), ('bias', tensor([0.4193]))])
# Loss:0.2007712423801422
# OrderedDict([('weight', tensor([1.0029])), ('bias', tensor([0.4188]))])
# Loss:0.2004232108592987
# OrderedDict([('weight', tensor([1.0045])), ('bias', tensor([0.4178]))])
# Loss:0.20008602738380432
# OrderedDict([('weight', tensor([1.0063])), ('bias', tensor([0.4173]))])
# Loss:0.1997370719909668
# OrderedDict([('weight', tensor([1.0081])), ('bias', tensor([0.4168]))])
# Loss:0.19939804077148438
# OrderedDict([('weight', tensor([1.0097])), ('bias', tensor([0.4158]))])
# Loss:0.1990518718957901
# OrderedDict([('weight', tensor([1.0115])), ('bias', tensor([0.4153]))])
# Loss:0.19870904088020325
# OrderedDict([('weight', tensor([1.0130])), ('bias', tensor([0.4143]))])
# Epoch: 300 | Test: 0.1983666718006134 | Test loss: 0.4629739820957184
# Loss:0.1983666718006134
# OrderedDict([('weight', tensor([1.0148])), ('bias', tensor([0.4138]))])
# Loss:0.19802001118659973
# OrderedDict([('weight', tensor([1.0164])), ('bias', tensor([0.4128]))])
# Loss:0.1976814717054367
# OrderedDict([('weight', tensor([1.0182])), ('bias', tensor([0.4123]))])
# Loss:0.1973324716091156
# OrderedDict([('weight', tensor([1.0200])), ('bias', tensor([0.4118]))])
# Loss:0.1969948261976242
# OrderedDict([('weight', tensor([1.0216])), ('bias', tensor([0.4108]))])
# Loss:0.1966473013162613
# OrderedDict([('weight', tensor([1.0234])), ('bias', tensor([0.4103]))])
# Loss:0.19630584120750427
# OrderedDict([('weight', tensor([1.0250])), ('bias', tensor([0.4093]))])
# Loss:0.1959621161222458
# OrderedDict([('weight', tensor([1.0268])), ('bias', tensor([0.4088]))])
# Loss:0.19561684131622314
# OrderedDict([('weight', tensor([1.0284])), ('bias', tensor([0.4078]))])
# Loss:0.1952769160270691
# OrderedDict([('weight', tensor([1.0302])), ('bias', tensor([0.4073]))])
# Epoch: 310 | Test: 0.19492791593074799 | Test loss: 0.45470181107521057
# Loss:0.19492791593074799
# OrderedDict([('weight', tensor([1.0320])), ('bias', tensor([0.4068]))])
# Loss:0.19459164142608643
# OrderedDict([('weight', tensor([1.0336])), ('bias', tensor([0.4058]))])
# Loss:0.19424273073673248
# OrderedDict([('weight', tensor([1.0354])), ('bias', tensor([0.4053]))])
# Loss:0.1939026415348053
# OrderedDict([('weight', tensor([1.0370])), ('bias', tensor([0.4043]))])
# Loss:0.1935575306415558
# OrderedDict([('weight', tensor([1.0388])), ('bias', tensor([0.4038]))])
# Loss:0.19321364164352417
# OrderedDict([('weight', tensor([1.0404])), ('bias', tensor([0.4028]))])
# Loss:0.19287234544754028
# OrderedDict([('weight', tensor([1.0422])), ('bias', tensor([0.4023]))])
# Loss:0.19252464175224304
# OrderedDict([('weight', tensor([1.0438])), ('bias', tensor([0.4013]))])
# Loss:0.19218716025352478
# OrderedDict([('weight', tensor([1.0456])), ('bias', tensor([0.4008]))])
# Loss:0.19183817505836487
# OrderedDict([('weight', tensor([1.0474])), ('bias', tensor([0.4003]))])
# Epoch: 320 | Test: 0.19149944186210632 | Test loss: 0.4471163749694824
# Loss:0.19149944186210632
# OrderedDict([('weight', tensor([1.0490])), ('bias', tensor([0.3993]))])
# Loss:0.19115298986434937
# OrderedDict([('weight', tensor([1.0508])), ('bias', tensor([0.3988]))])
# Loss:0.190810427069664
# OrderedDict([('weight', tensor([1.0523])), ('bias', tensor([0.3978]))])
# Loss:0.19046778976917267
# OrderedDict([('weight', tensor([1.0541])), ('bias', tensor([0.3973]))])
# Loss:0.19012144207954407
# OrderedDict([('weight', tensor([1.0557])), ('bias', tensor([0.3963]))])
# Loss:0.18978260457515717
# OrderedDict([('weight', tensor([1.0575])), ('bias', tensor([0.3958]))])
# Loss:0.18943361937999725
# OrderedDict([('weight', tensor([1.0593])), ('bias', tensor([0.3953]))])
# Loss:0.18909624218940735
# OrderedDict([('weight', tensor([1.0609])), ('bias', tensor([0.3943]))])
# Loss:0.18874843418598175
# OrderedDict([('weight', tensor([1.0627])), ('bias', tensor([0.3938]))])
# Loss:0.1884072721004486
# OrderedDict([('weight', tensor([1.0643])), ('bias', tensor([0.3928]))])
# Epoch: 330 | Test: 0.18806323409080505 | Test loss: 0.4388442039489746
# Loss:0.18806323409080505
# OrderedDict([('weight', tensor([1.0661])), ('bias', tensor([0.3923]))])
# Loss:0.1877182424068451
# OrderedDict([('weight', tensor([1.0677])), ('bias', tensor([0.3913]))])
# Loss:0.18737804889678955
# OrderedDict([('weight', tensor([1.0695])), ('bias', tensor([0.3908]))])
# Loss:0.18702925741672516
# OrderedDict([('weight', tensor([1.0711])), ('bias', tensor([0.3898]))])
# Loss:0.18669283390045166
# OrderedDict([('weight', tensor([1.0729])), ('bias', tensor([0.3893]))])
# Loss:0.18634386360645294
# OrderedDict([('weight', tensor([1.0747])), ('bias', tensor([0.3888]))])
# Loss:0.18600405752658844
# OrderedDict([('weight', tensor([1.0763])), ('bias', tensor([0.3878]))])
# Loss:0.18565866351127625
# OrderedDict([('weight', tensor([1.0781])), ('bias', tensor([0.3873]))])
# Loss:0.1853150725364685
# OrderedDict([('weight', tensor([1.0797])), ('bias', tensor([0.3863]))])
# Loss:0.18497349321842194
# OrderedDict([('weight', tensor([1.0815])), ('bias', tensor([0.3858]))])
# Epoch: 340 | Test: 0.18462607264518738 | Test loss: 0.4312588572502136
# Loss:0.18462607264518738
# OrderedDict([('weight', tensor([1.0831])), ('bias', tensor([0.3848]))])
# Loss:0.18428827822208405
# OrderedDict([('weight', tensor([1.0849])), ('bias', tensor([0.3843]))])
# Loss:0.18393929302692413
# OrderedDict([('weight', tensor([1.0867])), ('bias', tensor([0.3838]))])
# Loss:0.18360085785388947
# OrderedDict([('weight', tensor([1.0883])), ('bias', tensor([0.3828]))])
# Loss:0.18325410783290863
# OrderedDict([('weight', tensor([1.0901])), ('bias', tensor([0.3823]))])
# Loss:0.18291188776493073
# OrderedDict([('weight', tensor([1.0916])), ('bias', tensor([0.3813]))])
# Loss:0.18256892263889313
# OrderedDict([('weight', tensor([1.0934])), ('bias', tensor([0.3808]))])
# Loss:0.1822228580713272
# OrderedDict([('weight', tensor([1.0950])), ('bias', tensor([0.3798]))])
# Loss:0.18188372254371643
# OrderedDict([('weight', tensor([1.0968])), ('bias', tensor([0.3793]))])
# Loss:0.18153472244739532
# OrderedDict([('weight', tensor([1.0986])), ('bias', tensor([0.3788]))])
# Epoch: 350 | Test: 0.18119767308235168 | Test loss: 0.42298659682273865
# Loss:0.18119767308235168
# OrderedDict([('weight', tensor([1.1002])), ('bias', tensor([0.3778]))])
# Loss:0.18084953725337982
# OrderedDict([('weight', tensor([1.1020])), ('bias', tensor([0.3773]))])
# Loss:0.18050868809223175
# OrderedDict([('weight', tensor([1.1036])), ('bias', tensor([0.3763]))])
# Loss:0.1801643669605255
# OrderedDict([('weight', tensor([1.1054])), ('bias', tensor([0.3758]))])
# Loss:0.17981967329978943
# OrderedDict([('weight', tensor([1.1070])), ('bias', tensor([0.3748]))])
# Loss:0.17947916686534882
# OrderedDict([('weight', tensor([1.1088])), ('bias', tensor([0.3743]))])
# Loss:0.1791306585073471
# OrderedDict([('weight', tensor([1.1104])), ('bias', tensor([0.3733]))])
# Loss:0.17879396677017212
# OrderedDict([('weight', tensor([1.1122])), ('bias', tensor([0.3728]))])
# Loss:0.1784449964761734
# OrderedDict([('weight', tensor([1.1140])), ('bias', tensor([0.3723]))])
# Loss:0.17810548841953278
# OrderedDict([('weight', tensor([1.1156])), ('bias', tensor([0.3713]))])
# Epoch: 360 | Test: 0.1777597963809967 | Test loss: 0.41471433639526367
# Loss:0.1777597963809967
# OrderedDict([('weight', tensor([1.1174])), ('bias', tensor([0.3708]))])
# Loss:0.17741648852825165
# OrderedDict([('weight', tensor([1.1190])), ('bias', tensor([0.3698]))])
# Loss:0.17707459628582
# OrderedDict([('weight', tensor([1.1208])), ('bias', tensor([0.3693]))])
# Loss:0.17672748863697052
# OrderedDict([('weight', tensor([1.1224])), ('bias', tensor([0.3683]))])
# Loss:0.1763894259929657
# OrderedDict([('weight', tensor([1.1242])), ('bias', tensor([0.3678]))])
# Loss:0.1760404407978058
# OrderedDict([('weight', tensor([1.1260])), ('bias', tensor([0.3673]))])
# Loss:0.1757022887468338
# OrderedDict([('weight', tensor([1.1276])), ('bias', tensor([0.3663]))])
# Loss:0.1753552258014679
# OrderedDict([('weight', tensor([1.1294])), ('bias', tensor([0.3658]))])
# Loss:0.17501327395439148
# OrderedDict([('weight', tensor([1.1309])), ('bias', tensor([0.3648]))])
# Loss:0.1746700406074524
# OrderedDict([('weight', tensor([1.1327])), ('bias', tensor([0.3643]))])
# Epoch: 370 | Test: 0.17432430386543274 | Test loss: 0.4071289896965027
# Loss:0.17432430386543274
# OrderedDict([('weight', tensor([1.1343])), ('bias', tensor([0.3633]))])
# Loss:0.1739848554134369
# OrderedDict([('weight', tensor([1.1361])), ('bias', tensor([0.3628]))])
# Loss:0.17363587021827698
# OrderedDict([('weight', tensor([1.1379])), ('bias', tensor([0.3623]))])
# Loss:0.17329910397529602
# OrderedDict([('weight', tensor([1.1395])), ('bias', tensor([0.3613]))])
# Loss:0.1729506552219391
# OrderedDict([('weight', tensor([1.1413])), ('bias', tensor([0.3608]))])
# Loss:0.1726100891828537
# OrderedDict([('weight', tensor([1.1429])), ('bias', tensor([0.3598]))])
# Loss:0.17226547002792358
# OrderedDict([('weight', tensor([1.1447])), ('bias', tensor([0.3593]))])
# Loss:0.17192108929157257
# OrderedDict([('weight', tensor([1.1463])), ('bias', tensor([0.3583]))])
# Loss:0.17158028483390808
# OrderedDict([('weight', tensor([1.1481])), ('bias', tensor([0.3578]))])
# Loss:0.17123210430145264
# OrderedDict([('weight', tensor([1.1497])), ('bias', tensor([0.3568]))])
# Epoch: 380 | Test: 0.17089509963989258 | Test loss: 0.3988566994667053
# Loss:0.17089509963989258
# OrderedDict([('weight', tensor([1.1515])), ('bias', tensor([0.3563]))])
# Loss:0.17054611444473267
# OrderedDict([('weight', tensor([1.1533])), ('bias', tensor([0.3558]))])
# Loss:0.1702069193124771
# OrderedDict([('weight', tensor([1.1549])), ('bias', tensor([0.3548]))])
# Loss:0.16986092925071716
# OrderedDict([('weight', tensor([1.1567])), ('bias', tensor([0.3543]))])
# Loss:0.1695179045200348
# OrderedDict([('weight', tensor([1.1583])), ('bias', tensor([0.3533]))])
# Loss:0.16917572915554047
# OrderedDict([('weight', tensor([1.1601])), ('bias', tensor([0.3528]))])
# Loss:0.16882890462875366
# OrderedDict([('weight', tensor([1.1617])), ('bias', tensor([0.3518]))])
# Loss:0.16849055886268616
# OrderedDict([('weight', tensor([1.1635])), ('bias', tensor([0.3513]))])
# Loss:0.16814157366752625
# OrderedDict([('weight', tensor([1.1653])), ('bias', tensor([0.3508]))])
# Loss:0.16780368983745575
# OrderedDict([('weight', tensor([1.1669])), ('bias', tensor([0.3498]))])
# Epoch: 390 | Test: 0.16745635867118835 | Test loss: 0.3905845284461975
# Loss:0.16745635867118835
# OrderedDict([('weight', tensor([1.1687])), ('bias', tensor([0.3493]))])
# Loss:0.167114719748497
# OrderedDict([('weight', tensor([1.1702])), ('bias', tensor([0.3483]))])
# Loss:0.16677115857601166
# OrderedDict([('weight', tensor([1.1720])), ('bias', tensor([0.3478]))])
# Loss:0.16642571985721588
# OrderedDict([('weight', tensor([1.1736])), ('bias', tensor([0.3468]))])
# Loss:0.16608597338199615
# OrderedDict([('weight', tensor([1.1754])), ('bias', tensor([0.3463]))])
# Loss:0.16573698818683624
# OrderedDict([('weight', tensor([1.1772])), ('bias', tensor([0.3458]))])
# Loss:0.16540051996707916
# OrderedDict([('weight', tensor([1.1788])), ('bias', tensor([0.3448]))])
# Loss:0.16505178809165955
# OrderedDict([('weight', tensor([1.1806])), ('bias', tensor([0.3443]))])
# Loss:0.16471150517463684
# OrderedDict([('weight', tensor([1.1822])), ('bias', tensor([0.3433]))])
# Loss:0.16436660289764404
# OrderedDict([('weight', tensor([1.1840])), ('bias', tensor([0.3428]))])
# Epoch: 400 | Test: 0.1640225350856781 | Test loss: 0.38299909234046936
# Loss:0.1640225350856781
# OrderedDict([('weight', tensor([1.1856])), ('bias', tensor([0.3418]))])
# Loss:0.16368141770362854
# OrderedDict([('weight', tensor([1.1874])), ('bias', tensor([0.3413]))])
# Loss:0.16333350539207458
# OrderedDict([('weight', tensor([1.1890])), ('bias', tensor([0.3403]))])
# Loss:0.16299621760845184
# OrderedDict([('weight', tensor([1.1908])), ('bias', tensor([0.3398]))])
# Loss:0.16264724731445312
# OrderedDict([('weight', tensor([1.1926])), ('bias', tensor([0.3393]))])
# Loss:0.16230833530426025
# OrderedDict([('weight', tensor([1.1942])), ('bias', tensor([0.3383]))])
# Loss:0.16196203231811523
# OrderedDict([('weight', tensor([1.1960])), ('bias', tensor([0.3378]))])
# Loss:0.16161933541297913
# OrderedDict([('weight', tensor([1.1976])), ('bias', tensor([0.3368]))])
# Loss:0.16127684712409973
# OrderedDict([('weight', tensor([1.1994])), ('bias', tensor([0.3363]))])
# Loss:0.160930335521698
# OrderedDict([('weight', tensor([1.2010])), ('bias', tensor([0.3353]))])
# Epoch: 410 | Test: 0.16059166193008423 | Test loss: 0.3747268617153168
# Loss:0.16059166193008423
# OrderedDict([('weight', tensor([1.2028])), ('bias', tensor([0.3348]))])
# Loss:0.16024266183376312
# OrderedDict([('weight', tensor([1.2046])), ('bias', tensor([0.3343]))])
# Loss:0.15990515053272247
# OrderedDict([('weight', tensor([1.2062])), ('bias', tensor([0.3333]))])
# Loss:0.1595574915409088
# OrderedDict([('weight', tensor([1.2080])), ('bias', tensor([0.3328]))])
# Loss:0.15921613574028015
# OrderedDict([('weight', tensor([1.2095])), ('bias', tensor([0.3318]))])
# Loss:0.15887227654457092
# OrderedDict([('weight', tensor([1.2113])), ('bias', tensor([0.3313]))])
# Loss:0.15852713584899902
# OrderedDict([('weight', tensor([1.2129])), ('bias', tensor([0.3303]))])
# Loss:0.1581871062517166
# OrderedDict([('weight', tensor([1.2147])), ('bias', tensor([0.3298]))])
# Loss:0.1578381359577179
# OrderedDict([('weight', tensor([1.2163])), ('bias', tensor([0.3288]))])
# Loss:0.15750190615653992
# OrderedDict([('weight', tensor([1.2181])), ('bias', tensor([0.3283]))])
# Epoch: 420 | Test: 0.15715292096138 | Test loss: 0.3664546608924866
# Loss:0.15715292096138
# OrderedDict([('weight', tensor([1.2199])), ('bias', tensor([0.3278]))])
# Loss:0.15681293606758118
# OrderedDict([('weight', tensor([1.2215])), ('bias', tensor([0.3268]))])
# Loss:0.15646770596504211
# OrderedDict([('weight', tensor([1.2233])), ('bias', tensor([0.3263]))])
# Loss:0.15612392127513885
# OrderedDict([('weight', tensor([1.2249])), ('bias', tensor([0.3253]))])
# Loss:0.1557825356721878
# OrderedDict([('weight', tensor([1.2267])), ('bias', tensor([0.3248]))])
# Loss:0.1554349660873413
# OrderedDict([('weight', tensor([1.2283])), ('bias', tensor([0.3238]))])
# Loss:0.1550973355770111
# OrderedDict([('weight', tensor([1.2301])), ('bias', tensor([0.3233]))])
# Loss:0.1547483652830124
# OrderedDict([('weight', tensor([1.2319])), ('bias', tensor([0.3228]))])
# Loss:0.1544097363948822
# OrderedDict([('weight', tensor([1.2335])), ('bias', tensor([0.3218]))])
# Loss:0.1540631502866745
# OrderedDict([('weight', tensor([1.2353])), ('bias', tensor([0.3213]))])
# Epoch: 430 | Test: 0.15372075140476227 | Test loss: 0.3588692545890808
# Loss:0.15372075140476227
# OrderedDict([('weight', tensor([1.2369])), ('bias', tensor([0.3203]))])
# Loss:0.1533779799938202
# OrderedDict([('weight', tensor([1.2387])), ('bias', tensor([0.3198]))])
# Loss:0.15303176641464233
# OrderedDict([('weight', tensor([1.2403])), ('bias', tensor([0.3188]))])
# Loss:0.1526927649974823
# OrderedDict([('weight', tensor([1.2421])), ('bias', tensor([0.3183]))])
# Loss:0.15234379470348358
# OrderedDict([('weight', tensor([1.2439])), ('bias', tensor([0.3178]))])
# Loss:0.15200653672218323
# OrderedDict([('weight', tensor([1.2455])), ('bias', tensor([0.3168]))])
# Loss:0.15165860950946808
# OrderedDict([('weight', tensor([1.2473])), ('bias', tensor([0.3163]))])
# Loss:0.1513175666332245
# OrderedDict([('weight', tensor([1.2488])), ('bias', tensor([0.3153]))])
# Loss:0.15097340941429138
# OrderedDict([('weight', tensor([1.2506])), ('bias', tensor([0.3148]))])
# Loss:0.15062856674194336
# OrderedDict([('weight', tensor([1.2522])), ('bias', tensor([0.3138]))])
# Epoch: 440 | Test: 0.15028822422027588 | Test loss: 0.350597083568573
# Loss:0.15028822422027588
# OrderedDict([('weight', tensor([1.2540])), ('bias', tensor([0.3133]))])
# Loss:0.14993956685066223
# OrderedDict([('weight', tensor([1.2556])), ('bias', tensor([0.3123]))])
# Loss:0.14960303902626038
# OrderedDict([('weight', tensor([1.2574])), ('bias', tensor([0.3118]))])
# Loss:0.14925405383110046
# OrderedDict([('weight', tensor([1.2592])), ('bias', tensor([0.3113]))])
# Loss:0.1489143669605255
# OrderedDict([('weight', tensor([1.2608])), ('bias', tensor([0.3103]))])
# Loss:0.14856883883476257
# OrderedDict([('weight', tensor([1.2626])), ('bias', tensor([0.3098]))])
# Loss:0.1482253521680832
# OrderedDict([('weight', tensor([1.2642])), ('bias', tensor([0.3088]))])
# Loss:0.14788366854190826
# OrderedDict([('weight', tensor([1.2660])), ('bias', tensor([0.3083]))])
# Loss:0.14753636717796326
# OrderedDict([('weight', tensor([1.2676])), ('bias', tensor([0.3073]))])
# Loss:0.14719846844673157
# OrderedDict([('weight', tensor([1.2694])), ('bias', tensor([0.3068]))])
# Epoch: 450 | Test: 0.14684948325157166 | Test loss: 0.34232479333877563
# Loss:0.14684948325157166
# OrderedDict([('weight', tensor([1.2712])), ('bias', tensor([0.3063]))])
# Loss:0.14651116728782654
# OrderedDict([('weight', tensor([1.2728])), ('bias', tensor([0.3053]))])
# Loss:0.14616428315639496
# OrderedDict([('weight', tensor([1.2746])), ('bias', tensor([0.3048]))])
# Loss:0.1458221673965454
# OrderedDict([('weight', tensor([1.2762])), ('bias', tensor([0.3038]))])
# Loss:0.14547909796237946
# OrderedDict([('weight', tensor([1.2780])), ('bias', tensor([0.3033]))])
# Loss:0.14513316750526428
# OrderedDict([('weight', tensor([1.2796])), ('bias', tensor([0.3023]))])
# Loss:0.14479389786720276
# OrderedDict([('weight', tensor([1.2814])), ('bias', tensor([0.3018]))])
# Loss:0.14444491267204285
# OrderedDict([('weight', tensor([1.2832])), ('bias', tensor([0.3013]))])
# Loss:0.14410798251628876
# OrderedDict([('weight', tensor([1.2848])), ('bias', tensor([0.3003]))])
# Loss:0.14375972747802734
# OrderedDict([('weight', tensor([1.2866])), ('bias', tensor([0.2998]))])
# Epoch: 460 | Test: 0.14341895282268524 | Test loss: 0.3347393870353699
# Loss:0.14341895282268524
# OrderedDict([('weight', tensor([1.2881])), ('bias', tensor([0.2988]))])
# Loss:0.14307454228401184
# OrderedDict([('weight', tensor([1.2899])), ('bias', tensor([0.2983]))])
# Loss:0.1427299678325653
# ...
# Loss:0.00982770137488842
# OrderedDict([('weight', tensor([1.9528])), ('bias', tensor([0.0198]))])
# Epoch: 850 | Test: 0.009479062631726265 | Test loss: 0.02174093760550022
# Loss:0.009479062631726265
# OrderedDict([('weight', tensor([1.9544])), ('bias', tensor([0.0188]))])
# Loss:0.00914251059293747
# OrderedDict([('weight', tensor([1.9562])), ('bias', tensor([0.0183]))])
# Loss:0.008793503977358341
# OrderedDict([('weight', tensor([1.9580])), ('bias', tensor([0.0178]))])
# Loss:0.00845390185713768
# OrderedDict([('weight', tensor([1.9596])), ('bias', tensor([0.0168]))])
# Loss:0.00810831505805254
# OrderedDict([('weight', tensor([1.9614])), ('bias', tensor([0.0163]))])
# Loss:0.007764862384647131
# OrderedDict([('weight', tensor([1.9630])), ('bias', tensor([0.0153]))])
# Loss:0.007423133589327335
# OrderedDict([('weight', tensor([1.9648])), ('bias', tensor([0.0148]))])
# Loss:0.007075868546962738
# OrderedDict([('weight', tensor([1.9664])), ('bias', tensor([0.0138]))])
# Loss:0.006737942807376385
# OrderedDict([('weight', tensor([1.9682])), ('bias', tensor([0.0133]))])
# Loss:0.006388944573700428
# OrderedDict([('weight', tensor([1.9700])), ('bias', tensor([0.0128]))])
# Epoch: 860 | Test: 0.0060507082380354404 | Test loss: 0.013468766584992409
# Loss:0.0060507082380354404
# OrderedDict([('weight', tensor([1.9716])), ('bias', tensor([0.0118]))])
# Loss:0.005703759379684925
# OrderedDict([('weight', tensor([1.9734])), ('bias', tensor([0.0113]))])
# Loss:0.005361682735383511
# OrderedDict([('weight', tensor([1.9750])), ('bias', tensor([0.0103]))])
# Loss:0.0050185685977339745
# OrderedDict([('weight', tensor([1.9768])), ('bias', tensor([0.0098]))])
# Loss:0.004672662820667028
# OrderedDict([('weight', tensor([1.9784])), ('bias', tensor([0.0088]))])
# Loss:0.004333381541073322
# OrderedDict([('weight', tensor([1.9802])), ('bias', tensor([0.0083]))])
# Loss:0.00398437911644578
# OrderedDict([('weight', tensor([1.9820])), ('bias', tensor([0.0078]))])
# Loss:0.00364750437438488
# OrderedDict([('weight', tensor([1.9836])), ('bias', tensor([0.0068]))])
# Loss:0.003299193922430277
# OrderedDict([('weight', tensor([1.9854])), ('bias', tensor([0.0063]))])
# Loss:0.0029585049487650394
# OrderedDict([('weight', tensor([1.9870])), ('bias', tensor([0.0053]))])
# Epoch: 870 | Test: 0.002614002674818039 | Test loss: 0.005196595098823309
# Loss:0.002614002674818039
# OrderedDict([('weight', tensor([1.9888])), ('bias', tensor([0.0048]))])
# Loss:0.002269463613629341
# OrderedDict([('weight', tensor([1.9903])), ('bias', tensor([0.0038]))])
# Loss:0.0019313081866130233
# OrderedDict([('weight', tensor([1.9923])), ('bias', tensor([0.0038]))])
# Loss:0.0016422856133431196
# OrderedDict([('weight', tensor([1.9932])), ('bias', tensor([0.0013]))])
# Loss:0.0016746328910812736
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 880 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 890 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 900 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 910 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 920 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 930 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 940 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 950 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 960 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 970 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 980 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Epoch: 990 | Test: 0.006497792899608612 | Test loss: 0.003369927406311035
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# Loss:0.006497792899608612
# OrderedDict([('weight', tensor([1.9967])), ('bias', tensor([0.0063]))])
# Loss:0.005023225210607052
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])

# %%
with torch.inference_mode():
    ypreds_new=model_0(X_test)
    plot_predictions (predictions = ypreds_new)

# %%
#plotting the loss curves 
plt.plot(epoch_count, np.array(torch.tensor(loss_values).numpy()), label="Loss values ")
plt.plot(epoch_count,test_loss_values, label="Test loss value")
plt.title("Training and test loss zurves")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
#saving a model in pytorch
from pathlib    import Path 
# create models directory 
MODEL_PATH = Path("Models")
MODEL_PATH.mkdir(parents=True, exist_ok=True)

#create model save path 
MODEL_NAME= "01_pytorch_workflow_model_0.pth"
MODEL_SAVE_PATH = MODEL_PATH/MODEL_NAME
print(f"Saving model to : {MODEL_SAVE_PATH}") 

#3. SAVE THE MODEL SAVE DICT 
torch.save(obj=model_0.state_dict(),f=MODEL_SAVE_PATH)

## Loading the model of just the state dict 
#new instance of the linear regression model class 
loaded_model_0 = LinearRegressionModel()
#load the saved state_dict of model_0 into the new instance 
loaded_model_0.load_state_dict(torch.load(MODEL_SAVE_PATH))

print(loaded_model_0.state_dict())



#now make some predictions iwht our loaded model 
loaded_model_0.eval()
with torch.inference_mode():
    loaded_model_preds = loaded_model_0(X_test)
    print(loaded_model_preds)
# Out:
# Saving model to : Models/01_pytorch_workflow_model_0.pth
# OrderedDict([('weight', tensor([1.9928])), ('bias', tensor([-0.0037]))])
# tensor([[1.5905],
#         [1.6304],
#         [1.6703],
#         [1.7101],
#         [1.7500],
#         [1.7898],
#         [1.8297],
#         [1.8695],
#         [1.9094],
#         [1.9493]])

# %%
 #compared loaded model preds wiht origianl 
model_0.eval()
with  torch.inference_mode():
    y_preds = model_0(X_test)
    
print(y_preds==loaded_model_preds)
# Out:
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])

# %%
## Putting it all togherter 

import torch 
from torch import nn
import matplotlib.pyplot as plt

print(torch.__version__)
# Out:
# 2.2.2

# %%
#Data 
weight = 0.7 
bias = 0.3

#create range values 
start = 0 
end = 1
step = 0.02

#create X and Y (feautres and lables)
X = torch.arange(start,end,step).unsqueeze(dim=1)
Y = weight*X + bias 
print(X[:10], Y[:10])
# Out:
# tensor([[0.0000],
#         [0.0200],
#         [0.0400],
#         [0.0600],
#         [0.0800],
#         [0.1000],
#         [0.1200],
#         [0.1400],
#         [0.1600],
#         [0.1800]]) tensor([[0.3000],
#         [0.3140],
#         [0.3280],
#         [0.3420],
#         [0.3560],
#         [0.3700],
#         [0.3840],
#         [0.3980],
#         [0.4120],
#         [0.4260]])

# %%
#Splitting the data into training and test 
train_spilt = int(0.8*len(X))
X_train = X[:train_spilt]
Y_train = Y[:train_spilt]
X_test = X[train_spilt:]
Y_test = Y[train_spilt:]
plot_predictions(X_train,Y_train,X_test,Y_test)

# %%
#Buliding a pytorch linear model 
# Subclass nn.Module to make our model
class LinearRegressionModelV2(nn.Module):
    def __init__(self):
        super().__init__()
        # Use nn.Linear() for creating the model parameters
        self.linear_layer = nn.Linear(in_features=1,out_features=1)
    
    # Define the forward computation (input data x flows through nn.Linear())
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.linear_layer(x)

# Set the manual seed when creating the model (this isn't always need but is used for demonstrative purposes, try commenting it out and seeing what happens)
torch.manual_seed(42)
model_1 = LinearRegressionModelV2()
print(model_1, model_1.state_dict())
# Out:
# LinearRegressionModelV2(
#   (linear_layer): Linear(in_features=1, out_features=1, bias=True)
# ) OrderedDict([('linear_layer.weight', tensor([[0.7645]])), ('linear_layer.bias', tensor([0.8300]))])

# %%
# Create loss function
loss_fn = nn.L1Loss()

# Create optimizer
optimizer = torch.optim.SGD(params=model_1.parameters(), # optimize newly created model's parameters
                            lr=0.01)


torch.manual_seed(42)

# Set the number of epochs 
epochs = 10000 


for epoch in range(epochs):
    ### Training
    model_1.train() # train mode is on by default after construction

    # 1. Forward pass
    y_pred = model_1(X_train)

    # 2. Calculate loss
    loss = loss_fn(y_pred, y_train)

    # 3. Zero grad optimizer
    optimizer.zero_grad()

    # 4. Loss backward
    loss.backward()

    # 5. Step the optimizer
    optimizer.step()

    ### Testing
    model_1.eval() # put the model in evaluation mode for testing (inference)
    # 1. Forward pass
    with torch.inference_mode():
        test_pred = model_1(X_test)
    
        # 2. Calculate the loss
        test_loss = loss_fn(test_pred, y_test)

    if epoch % 100 == 0:
        print(f"Epoch: {epoch} | Train loss: {loss} | Test loss: {test_loss}")
with torch.inference_mode():
    ypreds_new = model_1(X_test)
    plot_predictions(predictions=ypreds_new)
# Out:
# Epoch: 0 | Train loss: 0.36974167823791504 | Test loss: 0.2780746817588806
# Epoch: 100 | Train loss: 0.23977896571159363 | Test loss: 0.530250072479248
# Epoch: 200 | Train loss: 0.20468580722808838 | Test loss: 0.47775641083717346
# Epoch: 300 | Train loss: 0.17034128308296204 | Test loss: 0.3977811932563782
# Epoch: 400 | Train loss: 0.136000394821167 | Test loss: 0.31711944937705994
# Epoch: 500 | Train loss: 0.10165722668170929 | Test loss: 0.23714487254619598
# Epoch: 600 | Train loss: 0.06731502711772919 | Test loss: 0.1564837396144867
# Epoch: 700 | Train loss: 0.03297308832406998 | Test loss: 0.07650978863239288
# Epoch: 800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 1900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 2900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 3900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 4900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 5900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 6900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 7900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 8900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9000 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9100 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9200 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9300 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9400 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9500 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9600 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9700 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9800 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746
# Epoch: 9900 | Train loss: 0.006613197736442089 | Test loss: 0.008651137351989746

# %%
with torch.inference_mode():
    ypreds_new = model_1(X_test)
    plot_predictions(predictions=ypreds_new)

# %%
y_preds = model_0(X_train)
y_preds.shape
# Out:
# torch.Size([40, 1])

# %%
#loss = loss_fn(y_preds,y_train)
#loss
y_train
# Out:
# tensor([[0.0000],
#         [0.0400],
#         [0.0800],
#         [0.1200],
#         [0.1600],
#         [0.2000],
#         [0.2400],
#         [0.2800],
#         [0.3200],
#         [0.3600],
#         [0.4000],
#         [0.4400],
#         [0.4800],
#         [0.5200],
#         [0.5600],
#         [0.6000],
#         [0.6400],
#         [0.6800],
#         [0.7200],
#         [0.7600],
#         [0.8000],
#         [0.8400],
#         [0.8800],
#         [0.9200],
#         [0.9600],
#         [1.0000],
#         [1.0400],
#         [1.0800],
#         [1.1200],
#         [1.1600],
#         [1.2000],
#         [1.2400],
#         [1.2800],
#         [1.3200],
#         [1.3600],
#         [1.4000],
#         [1.4400],
#         [1.4800],
#         [1.5200],
#         [1.5600]])

# %%
loss
# Out:
# tensor(0.0049, grad_fn=<MeanBackward0>)
